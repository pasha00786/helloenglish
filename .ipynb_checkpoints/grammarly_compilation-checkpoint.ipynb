# %%
import pandas as pd
import numpy as np

# %%
error = pd.read_csv('errors.csv')

# %%
error.head(5)
# Out:
#    SNo                                            Options           Error
# 0    1  ['How much are those shoes in the window over ...  No error found
# 1    2  ['How much are these shoes in the window over ...  No error found
# 2    3  ['How much are that shoes in the window over t...  No error found
# 3    4  ['How much are this shoes in the window over t...  No error found
# 4    5                    ['My brown skirt fit me well.']  No error found

# %%
error_1 = error[error['Error'] != 'No error found']

# %%
error_1.head()
# Out:
#     SNo                                Options  \
# 7     8    ['My brown skirt is fits me well.']
# 8     9   ['Mohan is go to be three in June.']
# 13   14        ['I prefer relax on weekends.']
# 15   16   ['I prefer to relaxed on weekends.']
# 20   21  ['John and I is good chess players.']
#
#                                         Error
# 7                         Incorrect verb form
# 8                         Incorrect verb form
# 13                               Missing word
# 15                    Non-infinitive after to
# 20  Incorrect verb form with compound subject

# %%
errors = error['Error']

# %%
errors = np.array(errors)

# %%
unique_errors, unique_error_counts = np.unique(errors, return_counts=True)

# %%
unique_error_counts
# Out:
# array([  2,   7,   5,   3,  14,   1,   4,   5,   1,  59,  17,   6,   1,
#          5,  86,   8,  24,  12,   3,  29,   4,   1,   2,   7,   1,   1,
#        632,   1,   1,   4,   1,   4,   5,  10,   1,   7,   6,   1,   1,
#          2])

# %%
index = np.where(unique_errors == 'No error found')
unique_errors = np.delete(unique_errors, index)
unique_error_counts = np.delete(unique_error_counts, index)

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize=(20,10))
plt.bar(unique_errors, unique_error_counts)
plt.xlabel('Type of Errors', fontsize = 18)
plt.ylabel('Count', fontsize = 18)
plt.tick_params(labelsize=16)
plt.xticks(rotation=90)
plt.show()
fig.savefig('errors_plot.png')

# %%
import seaborn as sns
fig, ax = plt.subplots(figsize=(25,10))
sns.set(style="darkgrid")
sns_plot = sns.countplot(ax=ax, y="Error", data=error_1)
fig = sns_plot.get_figure()
fig.savefig('output.png')
